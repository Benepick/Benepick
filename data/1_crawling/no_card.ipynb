# %%
import pandas as pd

# %%
card = pd.read_csv('./data/no_card.csv', encoding='utf-8')
credit_card = pd.read_csv('./data/credit_card.csv', encoding='cp949')

# %%
card
# Out:
#         id            card_name card_brand card_in_out_1 card_in_out_2  \
# 0        1        신한카드 Hi-Point       신한카드    해외겸용 8,000           NaN
# 1        2            신한카드 Love       신한카드    해외겸용 8,000           NaN
# 2        3            신한카드 Lady       신한카드    해외겸용 5,000           NaN
# 3        4    SK에너지 신한카드The you       신한카드    국내전용 7,000   해외겸용 12,000
# 4        5  GS칼텍스 신한카드Dream 100       신한카드    국내전용 7,000   해외겸용 12,000
# ...    ...                  ...        ...           ...           ...
# 2380  2381           삼프로TV 하나카드       하나카드   국내전용 15,000   해외겸용 15,000
# 2381  2382  SC제일은행-현대카드 M CHECK       현대카드       국내전용 없음       해외겸용 없음
# 2382  2383  SC제일은행-현대카드 X CHECK       현대카드       국내전용 없음       해외겸용 없음
# 2383  2384     네이버페이 머니 하나 체크카드       하나카드       국내전용 없음       해외겸용 없음
# 2384  2385          네이버페이 쇼핑엔로카       롯데카드   국내전용 10,000   해외겸용 10,000
#
#      card_in_out_3                                           card_img  \
# 0              NaN  https://api.card-gorilla.com:8080/storage/card...
# 1              NaN  https://api.card-gorilla.com:8080/storage/card...
# 2              NaN  https://api.card-gorilla.com:8080/storage/card...
# 3              NaN  https://api.card-gorilla.com:8080/storage/card...
# 4              NaN  https://api.card-gorilla.com:8080/storage/card...
# ...            ...                                                ...
# 2380           NaN  https://api.card-gorilla.com:8080/storage/card...
# 2381           NaN  https://api.card-gorilla.com:8080/storage/card...
# 2382           NaN  https://api.card-gorilla.com:8080/storage/card...
# 2383           NaN  https://api.card-gorilla.com:8080/storage/card...
# 2384           NaN  https://api.card-gorilla.com:8080/storage/card...
#
#        card_record                        card_overseas
# 0          전월실적 없음              VISA | mastercard | JCB
# 1     전월실적20 만원 이상  VISA | mastercard | AMEX | UnionPay
# 2     전월실적30 만원 이상         VISA | mastercard | UnionPay
# 3     전월실적30 만원 이상         VISA | mastercard | UnionPay
# 4     전월실적30 만원 이상                                 VISA
# ...            ...                                  ...
# 2380  전월실적30 만원 이상                                 VISA
# 2381       전월실적 없음                                 VISA
# 2382       전월실적 없음                                 VISA
# 2383  전월실적25 만원 이상                           mastercard
# 2384       전월실적 없음                    mastercard | AMEX
#
# [2385 rows x 9 columns]

# %%
filtered_credit_card = card[card['card_name'].isin(credit_card['card_name'])]
