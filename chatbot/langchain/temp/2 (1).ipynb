# %%
# !pip install -q grobid-client langchain openai faiss-cpu PyPDF2 tiktoken

# %%
import openai
from PyPDF2 import PdfReader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import ElasticVectorSearch, Pinecone, Weaviate, FAISS
import os

os.environ["OPENAI_API_KEY"] = "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"

# %%
from langchain.chat_models import ChatOpenAI

# %%
from langchain import OpenAI
from langchain.chains import AnalyzeDocumentChain
from langchain.chains.summarize import load_summarize_chain

llm = OpenAI(temperature=0, model="chat-gpt-3.5-turbo-0613")
summary_chain = load_summarize_chain(llm, chain_type="map_reduce")

summarize_document_chain = AnalyzeDocumentChain(combine_docs_chain=summary_chain)

# %%
# pip install tables
# Out:
# Collecting tables
#   Downloading tables-3.8.0-cp39-cp39-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 0.0/3.6 MB ? eta -:--:--
#      --- ------------------------------------ 0.3/3.6 MB 10.6 MB/s eta 0:00:01
#      -------------- ------------------------- 1.3/3.6 MB 17.1 MB/s eta 0:00:01
#      ---------------------------- ----------- 2.5/3.6 MB 20.2 MB/s eta 0:00:01
#      ---------------------------------------  3.6/3.6 MB 22.9 MB/s eta 0:00:01
#      ---------------------------------------- 3.6/3.6 MB 20.8 MB/s eta 0:00:00
# Collecting cython>=0.29.21 (from tables)
#   Obtaining dependency information for cython>=0.29.21 from https://files.pythonhosted.org/packages/f9/20/400f5caa238051c54534f8ae76f9b2fcf1cd4171e7eba8d50f0066aff2ba/Cython-3.0.2-cp39-cp39-win_amd64.whl.metadata
#   Downloading Cython-3.0.2-cp39-cp39-win_amd64.whl.metadata (3.2 kB)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\ssafy\appdata\local\programs\python\python39\lib\site-packages (from tables) (1.25.2)
# Requirement already satisfied: numexpr>=2.6.2 in c:\users\ssafy\appdata\local\programs\python\python39\lib\site-packages (from tables) (2.8.5)
# Collecting blosc2~=2.0.0 (from tables)
#   Downloading blosc2-2.0.0-cp39-cp39-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#      -------------------------- ------------- 1.3/2.0 MB 27.2 MB/s eta 0:00:01
#      ---------------------------------------- 2.0/2.0 MB 30.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\ssafy\appdata\roaming\python\python39\site-packages (from tables) (23.1)
# Collecting py-cpuinfo (from tables)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: msgpack in c:\users\ssafy\appdata\local\programs\python\python39\lib\site-packages (from blosc2~=2.0.0->tables) (1.0.5)
# Downloading Cython-3.0.2-cp39-cp39-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ----------------------- ---------------- 1.6/2.8 MB 52.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 44.6 MB/s eta 0:00:00
# Installing collected packages: py-cpuinfo, cython, blosc2, tables
# Successfully installed blosc2-2.0.0 cython-3.0.2 py-cpuinfo-9.0.0 tables-3.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import tables
import tabulate

# %%
# pip install tabulate
# Out:
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('filtered_benefit.csv', encoding='utf-8')

# %%
df
# Out:
#       Unnamed: 0  card_id      card_name card_category  \
# 0              0      1.0  신한카드 Hi-Point            소매
# 1              2      1.0  신한카드 Hi-Point         생활서비스
# 2              4      1.0  신한카드 Hi-Point         생활서비스
# 3              7      2.0      신한카드 Love            소매
# 4              8      2.0      신한카드 Love            음식
# ...          ...      ...            ...           ...
# 1123       14794   2565.0          I-PET            음식
# 1124       14795   2565.0          I-PET            소매
# 1125       14796   2565.0          I-PET            소매
# 1126       14801   2567.0    우리동네GS 삼성카드            소매
# 1127       14804   2567.0    우리동네GS 삼성카드            음식
#
#                                 content  \
# 0          백화점/할인점/홈쇼핑·온라인몰 1.0~5.0% 적립
# 1        S-OIL, 현대오일뱅크 주유 시 리터 당 60원 적립
# 2     SK텔레콤/KT/LG U+ 이동통신요금 1.0~5.0% 적립
# 3      국내 유명 백화점, 할인점, 온라인 쇼핑몰 최대 5% 할인
# 4           국내 유명 패밀리레스토랑, 커피 20~30% 할인
# ...                                 ...
# 1123                          커피 10% 할인
# 1124                         대형마트 5% 할인
# 1125                          편의점 5% 할인
# 1126              GS25 1%/5%/10% 결제일 할인
# 1127                커피전문점/배달앱 10% 결제일할인
#
#                                                  detail
# 0     롯데/ 현대백화점 마이신한포인트 1.0~5.0% 적립\r\n- 문화센타 등 비쇼핑 ...
# 1     S-OIL / 현대오일뱅크 주유 시 리터 당 60원 마이신한포인트 적립\r\n- S...
# 2     SK텔레콤/KT/LG U+ 이동통신요금 1.0~5.0% 적립\r\n- SK텔레콤/K...
# 3     국내 유명 백화점, 할인점, 온라인 쇼핑몰 최대 5% 할인\r\n- 백화점 : 현대...
# 4     유명 패밀리 레스토랑 20~30% 할인\r\n- 패밀리 레스토랑 : 아웃백, 카페마...
# ...                                                 ...
# 1123  커피 10% 할인\r\n- 스타벅스, 커피빈, 투썸플레이스, 폴바셋, 이디야\r\n...
# 1124  대형마트 5% 할인\r\n- 이마트, 롯데마트, 홈플러스\r\n- 월 최대 1만원 ...
# 1125  편의점 5% 할인\r\n- GS25, CU, 세븐일레븐\r\n- 월 최대 5천원 할...
# 1126  GS25 1%/5%/10% 결제일 할인\r\n- 서비스 안내: GS25 1%/5%/...
# 1127  커피전문점/배달앱 10% 결제일할인\r\n- 서비스안내: 커피전문점/배달앱 10% ...
#
# [1128 rows x 6 columns]

# %%
print(df['card_name'].unique())
print(len(df['card_name'].unique()))
# Out:
# ['신한카드 Hi-Point' '신한카드 Love' '신한카드 Lady' '신한카드 23.5°' '신한카드 The CLASSIC-Y'
#  '신한카드 B.Big(삑)' '신한카드 Simple+' '신한카드 Air Platinum#' '신한카드 Mr.Life'
#  '신한카드 YOLO ⓘ' '신한카드 The CLASSIC+' '신한카드 RPM+ Platinum#' '신한카드 YOLO Tasty'
#  '신한카드 Shopping' '신한카드 O2O' '신한카드 Simple Platinum#' '카카오페이 신한카드'
#  'EDIYA 신한카드 Tasty' '신한카드 Noon' '신한카드 Edu' '신세계 신한카드' '모바일 Tmoney 신한카드'
#  '신한카드 All Pass' '신한카드 Deep Dream' '신한카드 The CLASSIC-L' 'GS칼텍스 신한카드 Shine'
#  '신한카드 The BEST-F' '신한카드 Lesson Platinum#' '신한카드 Deep Oil'
#  '신한카드 Deep Dream Platinum+' '신한카드 Deep On Platinum+'
#  'SOCAR 제휴 SOCAR 신한카드' '신한카드 Deep Store' 'American Express Blue(아멕스블루)'
#  '삼성카앤모아카드' '아시아나 삼성지엔미플래티늄카드' '삼성카드 taptap O' '삼성카드 taptap S'
#  '아시아나 삼성애니패스플래티늄카드' 'CU·배달의민족 삼성카드 taptap' '삼성카드 지엔미+' '삼성카드 애니패스+'
#  '카라이프 삼성카드 DISCOUNT+' '삼성카드 taptap I' '스카이패스 삼성아멕스카드' '글로벌쇼핑 삼성카드 5v2'
#  '삼성페이 삼성카드 taptap' '신세계이마트 삼성카드7' '트레이더스신세계 삼성카드' '카드의정석 NEW우리V카드'
#  'All For Me카드' '위비멤버스카드' '썸(SUM) 페이 카드' '위메프 우리카드' '우리 XGOLF 카드'
#  '카드의정석 POINT' '카드의정석 SHOPPING' '카드의정석 DISCOUNT' 'DA@카드의정석' 'D4@카드의정석'
#  '우리Most카드' '카드의정석 PREMIUM POINT' '카드의정석 PREMIUM MILEAGE(SKYPASS)'
#  '카드의정석 PREMIUM MILEAGE(AsianaClub)' 'LoL CHAMPIONS KOREA 우리카드'
#  'NEW 씨티 클리어' '굿데이카드' 'SK LPG SAVE KB국민카드' '와이즈카드' 'SK에너지 러브유 KB국민카드'
#  'GS행복가득카드' '굿데이올림카드' '청춘대로카드' '다담카드' '모바일101카드' 'E1 LPG KB국민카드'
#  '청춘대로 매니아i카드' '청춘대로 1코노미 카드' 'BeV Ⅲ 카드' '탄탄대로 온리유카드' 'S-OIL LPG KB국민카드'
#  'KB국민 펫코노미 카드' '톡톡 Pay카드' '청춘대로 꿀맛α카드' '청춘대로 꿀잠α카드' '삼성페이 KB국민카드' '에듀카드'
#  'Shopping Save카드' 'NC다이노스카드' '#ing(샵핑)카드' '#ing+(샵핑플러스)카드' 'ME+(미플러스)카드'
#  '부자되세요 HomeShopping카드(비씨)' 'NH올원 All100(올백)카드'
#  'NH올원 Shopping&11번가카드(R2타입)' 'NH올원 파이카드' 'SolSol++(쏠쏠투플러스)카드'
#  'SolSol(쏠쏠)카드' 'NH20 해봄카드' 'NH농협 부자되세요 아파트카드(비씨)' 'NH농협 콕카드' '올바른OIL카드'
#  '올바른TRAVEL카드(일본특화)' '올바른TRAVEL카드(중국특화)' 'T라이트카드' 'KT수퍼할부카드(비씨)'
#  'NH올원 LGU+카드' '롯데포인트 플러스 카드' '올마이쇼핑 카드 (해외)' '롯데백화점 롯데카드' 'ALL MY DC'
#  'ALL MY POINT' 'ALL MY LIVING' 'ALL MY DRIVING' '경차 smart 롯데카드'
#  'I’m GREAT' 'I’m CHEERFUL' 'I’m JOYFUL' 'CLUB SK(클럽 SK)카드'
#  '하나멤버스 1Q(원큐) 카드 Living' '하나멤버스 1Q(원큐) 카드 Shopping'
#  '하나멤버스 1Q(원큐) 카드 Daily' '하나멤버스 1Q카드 내맘대로' '1Q Daily+' '1Q Shopping+'
#  '1Q Living+' '1Q Special+' 'Mile 1.6 대한항공' 'Mile 1.6 아시아나'
#  'Mile 1.8 대한항공' 'Mile 1.8 아시아나' '통커 카드' '#tag1카드 Orange' '#tag1카드 Navy'
#  'my pass 마패 카드' '1Q My Lunch' 'Oil & Life카드(Oil카드)'
#  'Oil & Life카드(Life카드)' '참! 좋은 kt wiz 카드(신용)' 'olleh Super DC IBK카드'
#  '원더카드 LIVING' '원더카드 HAPPY' '원더카드 T' '신한카드 구독 좋아요' '삼성 iD NOMAD 카드'
#  'THE iD. PLATINUM(포인트)' 'THE iD. TITANIUM(포인트)' 'LOCA Mobility 반띵 카드'
#  '신세계 the Mile 하나카드' '신한카드 알뜰More(알뜰모아)' 'KMVNO 알뜰폰 카드'
#  'SKT-현대카드M Edition3(라이트할부형2.0)' 'MY RENTAL+ 롯데카드' 'T-economy KB국민카드'
#  'NU AUTO 우리카드' 'T나는혜택 삼성카드' '제주신화월드 신한카드' '수소차 충전할인 신한카드' '신한 햇살론카드'
#  'I-ALL' 'IBK DC히어로즈 카드(신용)' 'kt SUPER+ 카드' 'kt SUPER 카드' '베베쿡 신한카드'
#  'K-FIRST (모바일전용)' '신세계사이먼 프리미엄 아울렛 신한카드' '부자되세요 The Oil 카드' 'UPTURN카드'
#  '키자니아 에듀카드' '팟(pod) 카드' '오늘은e 신용카드' 'KT NU우리카드' 'LG U+ 우리카드' '만나 우리카드'
#  'LG트윈스 신한카드' '트래블로그 신용카드' '에너지 더블 카드' 'LOCA for 롯데마트' 'MY S-OIL 삼성카드'
#  'zgm.play++카드' '알뜰교통플러스 카드' '알뜰교통플러스' '알뜰교통플러스 삼성카드' 'I-알뜰교통플러스 카드(신용)'
#  '알뜰교통카드(신용)' '[광주] K-그린카드v2' 'I-PET' '우리동네GS 삼성카드']
# 498

# %%
card_name = pd.DataFrame(df['card_name'].unique())

# %%
from langchain.agents import create_pandas_dataframe_agent

# %%
prompt = create_pandas_dataframe_agent(OpenAI(temperature=0, max_tokens=1024), card_name, verbose=False)

# %%
df = pd.read_csv('filtered_benefit.csv', encoding='utf-8')

# %%
df = df[["card_name", "card_category", "content"]]

# %%
df = df.head()

# %%
df.columns = ['카드', '혜택', '혜택상세']
df
# Out:
#                  카드     혜택                               혜택상세
# 0     신한카드 Hi-Point     소매       백화점/할인점/홈쇼핑·온라인몰 1.0~5.0% 적립
# 1     신한카드 Hi-Point  생활서비스     S-OIL, 현대오일뱅크 주유 시 리터 당 60원 적립
# 2     신한카드 Hi-Point  생활서비스  SK텔레콤/KT/LG U+ 이동통신요금 1.0~5.0% 적립
# 3         신한카드 Love     소매   국내 유명 백화점, 할인점, 온라인 쇼핑몰 최대 5% 할인
# 4         신한카드 Love     음식        국내 유명 패밀리레스토랑, 커피 20~30% 할인
# ...             ...    ...                                ...
# 1123          I-PET     음식                          커피 10% 할인
# 1124          I-PET     소매                         대형마트 5% 할인
# 1125          I-PET     소매                          편의점 5% 할인
# 1126    우리동네GS 삼성카드     소매              GS25 1%/5%/10% 결제일 할인
# 1127    우리동네GS 삼성카드     음식                커피전문점/배달앱 10% 결제일할인
#
# [1128 rows x 3 columns]

# %%
df
# Out:
#                  카드     혜택                               혜택상세
# 0     신한카드 Hi-Point     소매       백화점/할인점/홈쇼핑·온라인몰 1.0~5.0% 적립
# 1     신한카드 Hi-Point  생활서비스     S-OIL, 현대오일뱅크 주유 시 리터 당 60원 적립
# 2     신한카드 Hi-Point  생활서비스  SK텔레콤/KT/LG U+ 이동통신요금 1.0~5.0% 적립
# 3         신한카드 Love     소매   국내 유명 백화점, 할인점, 온라인 쇼핑몰 최대 5% 할인
# 4         신한카드 Love     음식        국내 유명 패밀리레스토랑, 커피 20~30% 할인
# ...             ...    ...                                ...
# 1123          I-PET     음식                          커피 10% 할인
# 1124          I-PET     소매                         대형마트 5% 할인
# 1125          I-PET     소매                          편의점 5% 할인
# 1126    우리동네GS 삼성카드     소매              GS25 1%/5%/10% 결제일 할인
# 1127    우리동네GS 삼성카드     음식                커피전문점/배달앱 10% 결제일할인
#
# [1128 rows x 3 columns]

# %%
df[df['card_name'] == 'I-PET']
# Out:
#      card_name card_category             content
# 1121     I-PET         생활서비스  동물병원/반려동물업종 30% 할인
# 1122     I-PET         생활서비스      반려동물사진관 30% 할인
# 1123     I-PET            음식           커피 10% 할인
# 1124     I-PET            소매          대형마트 5% 할인
# 1125     I-PET            소매           편의점 5% 할인

# %%
from langchain.agents import create_pandas_dataframe_agent
from langchain.agents.types import AgentType

# %%
prompt = create_pandas_dataframe_agent(ChatOpenAI(temperature=0, max_tokens=1024, model="gpt-3.5-turbo-0613"), df, verbose=False, agent_type=AgentType.OPENAI_FUNCTIONS)

# %%
prompt.run("카드 목록 알려줘") # 컬럼명을 못찾음
# prompt.run("card_name 목록 알려줘") # 찾음
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain\agents\openai_functions_agent\base.py:112, in _parse_ai_message(message)
#     111 try:
# --> 112     _tool_input = json.loads(function_call["arguments"])
#     113 except JSONDecodeError:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1264.0_x64__qbz5n2kfra8p0\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1264.0_x64__qbz5n2kfra8p0\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.1264.0_x64__qbz5n2kfra8p0\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# OutputParserException                     Traceback (most recent call last)
# c:\Users\SSAFY\Desktop\A610\S09P22A610\chatbot\langchain\2 (1).ipynb Cell 22 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/Desktop/A610/S09P22A610/chatbot/langchain/2%20%281%29.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> prompt.run("카드 목록 알려줘") # 컬럼명을 못찾음
#       <a href='vscode-notebook-cell:/c%3A/Users/SSAFY/Desktop/A610/S09P22A610/chatbot/langchain/2%20%281%29.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> # prompt.run("card_name 목록 알려줘") # 찾음
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain\chains\base.py:487, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     485     if len(args) != 1:
#     486         raise ValueError("`run` supports only one positional argument.")
# --> 487     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     488         _output_key
#     489     ]
#     491 if kwargs and not args:
#     492     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     493         _output_key
#     494     ]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain\chains\base.py:292, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     290 except (KeyboardInterrupt, Exception) as e:
#     291     run_manager.on_chain_error(e)
# --> 292     raise e
#     293 run_manager.on_chain_end(outputs)
#     294 final_outputs: Dict[str, Any] = self.prep_outputs(
#     295     inputs, outputs, return_only_outputs
#     296 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain\chains\base.py:286, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     279 run_manager = callback_manager.on_chain_start(
#     280     dumpd(self),
#     281     inputs,
#     282     name=run_name,
#     283 )
#     284 try:
#     285     outputs = (
# --> 286         self._call(inputs, run_manager=run_manager)
#     287         if new_arg_supported
#     288         else self._call(inputs)
#     289     )
#     290 except (KeyboardInterrupt, Exception) as e:
#     291     run_manager.on_chain_error(e)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain\agents\agent.py:1039, in AgentExecutor._call(self, inputs, run_manager)
#    1037 # We now enter the agent loop (until it returns something).
#    1038 while self._should_continue(iterations, time_elapsed):
# -> 1039     next_step_output = self._take_next_step(
#    1040         name_to_tool_map,
#    1041         color_mapping,
#    1042         inputs,
#    1043         intermediate_steps,
#    1044         run_manager=run_manager,
#    1045     )
#    1046     if isinstance(next_step_output, AgentFinish):
#    1047         return self._return(
#    1048             next_step_output, intermediate_steps, run_manager=run_manager
#    1049         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain\agents\agent.py:847, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#     845     raise_error = False
#     846 if raise_error:
# --> 847     raise e
#     848 text = str(e)
#     849 if isinstance(self.handle_parsing_errors, bool):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain\agents\agent.py:836, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#     833     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#     835     # Call the LLM to see what to do.
# --> 836     output = self.agent.plan(
#     837         intermediate_steps,
#     838         callbacks=run_manager.get_child() if run_manager else None,
#     839         **inputs,
#     840     )
#     841 except OutputParserException as e:
#     842     if isinstance(self.handle_parsing_errors, bool):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain\agents\openai_functions_agent\base.py:221, in OpenAIFunctionsAgent.plan(self, intermediate_steps, callbacks, with_functions, **kwargs)
#     216 else:
#     217     predicted_message = self.llm.predict_messages(
#     218         messages,
#     219         callbacks=callbacks,
#     220     )
# --> 221 agent_decision = _parse_ai_message(predicted_message)
#     222 return agent_decision
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\langchain\agents\openai_functions_agent\base.py:114, in _parse_ai_message(message)
#     112     _tool_input = json.loads(function_call["arguments"])
#     113 except JSONDecodeError:
# --> 114     raise OutputParserException(
#     115         f"Could not parse tool input: {function_call} because "
#     116         f"the `arguments` is not valid JSON."
#     117     )
#     119 # HACK HACK HACK:
#     120 # The code that encodes tool input into Open AI uses a special variable
#     121 # name called `__arg1` to handle old style tools that do not expose a
#     122 # schema and expect a single string argument as an input.
#     123 # We unpack the argument here if it exists.
#     124 # Open AI does not support passing in a JSON array as an argument.
#     125 if "__arg1" in _tool_input:
#
# OutputParserException: Could not parse tool input: {'name': 'python', 'arguments': "card_list = df['card_name'].unique()\ncard_list"} because the `arguments` is not valid JSON.

# %%
max_context_length = 4096 # 최대 문맥 길이
max_tokens = 1024 # 최대 토큰 길이

# 입력을 여러 번 요청하는 함수
def generate_text(prompt):
    # 요청 문장의 길이가 최대 문맥 길이를 초과하는 경우 나누어 요청
    if len(prompt) > max_context_length:
        prompt_chunks = [prompt[i:i+max_context_length] for i in range(0, len(prompt), max_context_length)]
    else:
        prompt_chunks = [prompt]

    response_texts = []
    openai.api_base =  OPENAI_BASE
    openai.api_type = OPENAI_TYPE
    openai.api_version = OPENAI_VERSION # this may change in the future
    openai.api_key = OPENAI_API_KEY
    for chunk in prompt_chunks:
        # OpenAI API로 요청
        response = openai.Completion.create(
            engine=OPENAI_DEPLOYMENT_SUMMARY,
            prompt=chunk,
            max_tokens=max_tokens,
            temperature=0.9,
            top_p=1,
            stop=None,
            frequency_penalty=0,
            presence_penalty=0.6
        )
        response_text = response.choices[0].text.strip()
        response_texts.append(response_text)

    # 결과를 하나로 합쳐서 반환
    return " ".join(response_texts)

retry_count = 0
summary_result = ''
while retry_count < 3:
    try:
        start_phrase = f'Summariaz to korean the text below in without adding new information.\n\n[Start of text]{openai_text}[End of text]'
        summary_result = generate_text(start_phrase)
        return summary_result
    except Exception as generate_text_error:
        print(f'generate_text Error: {generate_text_error.args}')
        retry_count += 1
        time.sleep(1)
